# %%
import Image_seg_main as iis
import importlib
importlib.reload(iis)
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Balloon (2 regions)

# %% [markdown]
# ## Get scribbles from scrib.npy file

# %%
#we load scribbles created with the script Get_scribbles.py
line_scribbles = np.load('Scrib/scrib1_ballon.npy', allow_pickle='TRUE')
line_scribbles = line_scribbles.item()

# %%
im = plt.imread('Images/petit_ballon.jpeg').astype(float)/255
print(im.shape)
iis.plot_scribbles(im,line_scribbles)
# Out:
# (492, 423, 3)

# %% [markdown]
# ## Compute f & compute g

# %%
#we can choose parameters (default values are detailed in the main.py file)
options = dict([('alpha',1.8),('sigma',0.5)])

# %%
#compute f
f,_ = iis.compute_f(im,line_scribbles,options = options)

# %%
#compute g
g = iis.fct_g(im)

# %% [markdown]
# ## Primal-Dual optimization

# %%
Theta_t1, Primal_energies, Dual_energies, Gap = iis.primal_dual_optimization(f,g,im,options = options)
# Out:
# /Users/marion/Desktop/MVA/Cours MVA/S2/Discrete_inf/Projet_image_seg/Project_CHAUVEAU_Code/Image_seg_main.py:150: RuntimeWarning: invalid value encountered in true_divide
#   Projected_Ksi= Ksi*Mask1 + Mask2*(g.reshape((1,*g.shape,1))/2)*(Ksi/Norm_ax3_ksi.reshape((*Norm_ax3_ksi.shape,1)))
# Iteration = 0 ; Dual energy = -70543.92517212353 ; Primal Energy = 19213374.449734397 ; Gap = 19283918.37490652

# %% [markdown]
# ## Plot Energies

# %%
iis.plot_energies(Primal_energies,Dual_energies,Gap)

# %% [markdown]
# # Rabbit (2 regions)

# %% [markdown]
# ## Get scribbles from scrib.npy file

# %%
#we load scribbles created with the script Get_scribbles.py
line_scribbles = np.load('Scrib/scrib_lapin.npy', allow_pickle='TRUE')
line_scribbles = line_scribbles.item()

# %%
im = plt.imread('Images/lapin.jpeg').astype(float)/255
print(im.shape)
iis.plot_scribbles(im,line_scribbles)
# Out:
# (653, 826, 3)

# %% [markdown]
# ## Compute f & compute g

# %%
#we can choose parameters (default values are detailed in the main.py file)
options = dict([('alpha',1.8),('sigma',0.1)])

# %%
#compute f
f,_ = iis.compute_f(im,line_scribbles,options = options)

# %%
#compute g
g = iis.fct_g(im)

# %% [markdown]
# ## Primal-Dual optimization

# %%
Theta_t1, Primal_energies, Dual_energies, Gap = iis.primal_dual_optimization(f,g,im,options = options)
# Out:
# /Users/marion/Desktop/MVA/Cours MVA/S2/Discrete_inf/Projet_image_seg/Project_CHAUVEAU/Image_seg_main.py:150: RuntimeWarning: invalid value encountered in true_divide
#   Projected_Ksi= Ksi*Mask1 + Mask2*(g.reshape((1,*g.shape,1))/2)*(Ksi/Norm_ax3_ksi.reshape((*Norm_ax3_ksi.shape,1)))
# Iteration = 0 ; Dual energy = -149854.17138547567 ; Primal Energy = 39972916.55621871 ; Gap = 40122770.72760419

# %% [markdown]
# ## Plot Energies

# %%
iis.plot_energies(Primal_energies,Dual_energies,Gap)

# %% [markdown]
# # Flowers (3 regions)

# %% [markdown]
# ## Get scribbles from scrib.npy file

# %%
#we load scribbles created with the script Get_scribbles.py
line_scribbles = np.load('Scrib/scrib_flowers.npy', allow_pickle='TRUE')
line_scribbles = line_scribbles.item()

# %%
im = plt.imread('Images/flowers.jpg').astype(float)/255
print(im.shape)
iis.plot_scribbles(im,line_scribbles)
# Out:
# (321, 481, 3)

# %% [markdown]
# ## Compute f & compute g

# %%
#we can choose parameters (default values are detailed in the main.py file)
options = dict([('alpha',1.8),('sigma',0.1)])

# %%
#compute f
f,_ = iis.compute_f(im,line_scribbles,options = options)

# %%
#compute g
g = iis.fct_g(im)

# %% [markdown]
# ## Primal-Dual optimization

# %%
Theta_t1, Primal_energies, Dual_energies, Gap = iis.primal_dual_optimization(f,g,im, options = options)
# Out:
# /Users/marion/Desktop/MVA/Cours MVA/S2/Discrete_inf/Projet_image_seg/Project_CHAUVEAU/Image_seg_main.py:150: RuntimeWarning: invalid value encountered in true_divide
#   Projected_Ksi= Ksi*Mask1 + Mask2*(g.reshape((1,*g.shape,1))/2)*(Ksi/Norm_ax3_ksi.reshape((*Norm_ax3_ksi.shape,1)))
# Iteration = 0 ; Dual energy = -68803.54035751258 ; Primal Energy = 14912758.715016423 ; Gap = 14981562.255373936

# %% [markdown]
# ## Plot Energies

# %%
iis.plot_energies(Primal_energies,Dual_energies,Gap)
